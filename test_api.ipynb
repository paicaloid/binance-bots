# %%
from binance.client import Client
from dotenv import load_dotenv, find_dotenv
import os

# %%
from utils.helpers import get_balances, get_symbol_info

# %%
load_dotenv(find_dotenv(filename=".env.local", raise_error_if_not_found=True), override=True)
# Out:
# True

# %%
API_KEY = os.getenv('API_KEY')
API_SECRET = os.getenv('API_SECRET')

# %%
client = Client(api_key=API_KEY, api_secret=API_SECRET)

# %%
res = get_balances(client=client)

# %%
info = get_symbol_info(client=client, symbol='OPUSDT')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/pai/binance-bots/test_api.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Btesla-12/home/pai/binance-bots/test_api.ipynb#X43sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> info = get_symbol_info(client=client, symbol='OPUSDT')
#
# File ~/binance-bots/utils/helpers.py:70, in get_symbol_info(client, symbol)
#      46     raise ValueError("Symbol not found")
#      48 filters = {item.get("filterType"): item for item in info.get("filters")}
#      50 return Symbol(
#      51     symbol=info.get("symbol"),
#      52     base_asset=info.get("baseAsset"),
#      53     quote_asset=info.get("quoteAsset"),
#      54     price_filter=PriceFilter(
#      55         min_price=float(filters.get("PRICE_FILTER").get("minPrice")),
#      56         max_price=float(filters.get("PRICE_FILTER").get("maxPrice")),
# ...

# %%
res.get("USDT"), res.get("OP")
# Out:
# ({'asset': 'USDT', 'free': '2.02200125', 'locked': '0.00000000'},
#  {'asset': 'OP', 'free': '10.98088000', 'locked': '0.00000000'})

# %%
ss = client.get_symbol_info('OPUSDT')

# %%
ss
# Out:
# {'symbol': 'OPUSDT',
#  'status': 'TRADING',
#  'baseAsset': 'OP',
#  'baseAssetPrecision': 8,
#  'quoteAsset': 'USDT',
#  'quotePrecision': 8,
#  'quoteAssetPrecision': 8,
#  'baseCommissionPrecision': 8,
#  'quoteCommissionPrecision': 8,
#  'orderTypes': ['LIMIT',
#   'LIMIT_MAKER',
#   'MARKET',
#   'STOP_LOSS_LIMIT',
#   'TAKE_PROFIT_LIMIT'],
#  'icebergAllowed': True,
#  'ocoAllowed': True,
#  'quoteOrderQtyMarketAllowed': True,
#  'allowTrailingStop': True,
#  'cancelReplaceAllowed': True,
#  'isSpotTradingAllowed': True,
#  'isMarginTradingAllowed': True,
#  'filters': [{'filterType': 'PRICE_FILTER',
#    'minPrice': '0.00100000',
#    'maxPrice': '1000.00000000',
#    'tickSize': '0.00100000'},
#   {'filterType': 'LOT_SIZE',
#    'minQty': '0.01000000',
#    'maxQty': '92141578.00000000',
#    'stepSize': '0.01000000'},
#   {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#   {'filterType': 'MARKET_LOT_SIZE',
#    'minQty': '0.00000000',
#    'maxQty': '988423.47204166',
# ...

# %%
ss.get("filters")
# Out:
# [{'filterType': 'PRICE_FILTER',
#   'minPrice': '0.00100000',
#   'maxPrice': '1000.00000000',
#   'tickSize': '0.00100000'},
#  {'filterType': 'LOT_SIZE',
#   'minQty': '0.01000000',
#   'maxQty': '92141578.00000000',
#   'stepSize': '0.01000000'},
#  {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#  {'filterType': 'MARKET_LOT_SIZE',
#   'minQty': '0.00000000',
#   'maxQty': '988423.47204166',
#   'stepSize': '0.00000000'},
#  {'filterType': 'TRAILING_DELTA',
#   'minTrailingAboveDelta': 10,
#   'maxTrailingAboveDelta': 2000,
#   'minTrailingBelowDelta': 10,
#   'maxTrailingBelowDelta': 2000},
#  {'filterType': 'PERCENT_PRICE_BY_SIDE',
#   'bidMultiplierUp': '5',
#   'bidMultiplierDown': '0.2',
#   'askMultiplierUp': '5',
#   'askMultiplierDown': '0.2',
#   'avgPriceMins': 5},
#  {'filterType': 'NOTIONAL',
#   'minNotional': '5.00000000',
#   'applyMinToMarket': True,
#   'maxNotional': '9000000.00000000',
#   'applyMaxToMarket': False,
#   'avgPriceMins': 5},
# ...

# %%
{item.get("filterType"): item for item in ss.get("filters")}
# Out:
# {'PRICE_FILTER': {'filterType': 'PRICE_FILTER',
#   'minPrice': '0.00100000',
#   'maxPrice': '1000.00000000',
#   'tickSize': '0.00100000'},
#  'LOT_SIZE': {'filterType': 'LOT_SIZE',
#   'minQty': '0.01000000',
#   'maxQty': '92141578.00000000',
#   'stepSize': '0.01000000'},
#  'ICEBERG_PARTS': {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#  'MARKET_LOT_SIZE': {'filterType': 'MARKET_LOT_SIZE',
#   'minQty': '0.00000000',
#   'maxQty': '988423.47204166',
#   'stepSize': '0.00000000'},
#  'TRAILING_DELTA': {'filterType': 'TRAILING_DELTA',
#   'minTrailingAboveDelta': 10,
#   'maxTrailingAboveDelta': 2000,
#   'minTrailingBelowDelta': 10,
#   'maxTrailingBelowDelta': 2000},
#  'PERCENT_PRICE_BY_SIDE': {'filterType': 'PERCENT_PRICE_BY_SIDE',
#   'bidMultiplierUp': '5',
#   'bidMultiplierDown': '0.2',
#   'askMultiplierUp': '5',
#   'askMultiplierDown': '0.2',
#   'avgPriceMins': 5},
#  'NOTIONAL': {'filterType': 'NOTIONAL',
#   'minNotional': '5.00000000',
# ...

# %%
client.get_order_book(symbol="OPUSDT", limit=5)
# Out:
# {'lastUpdateId': 1398267458,
#  'bids': [['1.36800000', '11676.13000000'],
#   ['1.36700000', '41914.42000000'],
#   ['1.36600000', '99636.90000000'],
#   ['1.36500000', '84787.37000000'],
#   ['1.36400000', '55006.40000000']],
#  'asks': [['1.36900000', '19300.69000000'],
#   ['1.37000000', '104719.50000000'],
#   ['1.37100000', '149200.20000000'],
#   ['1.37200000', '147877.91000000'],
#   ['1.37300000', '52260.12000000']]}

# %%
from binance.enums import *
order = client.create_order(
    symbol="OPUSDT",
    side=SIDE_BUY,
    type=ORDER_TYPE_LIMIT,
    timeInForce=TIME_IN_FORCE_GTC,
    quantity=10,
    price='1.384')

# %%
from binance.enums import *
order = client.create_order(
    symbol="OPUSDT",
    side=SIDE_SELL,
    type=ORDER_TYPE_TAKE_PROFIT_LIMIT,
    timeInForce=TIME_IN_FORCE_GTC,
    quantity=9,
    stopPrice='1.400',
    price='1.384',
    trailingDelta='200'
)

# %%
client.get_order(
    symbol='OPUSDT',
    orderId='739197567'
)
# Out:
# {'symbol': 'OPUSDT',
#  'orderId': 739197567,
#  'orderListId': -1,
#  'clientOrderId': 'dMjyZvwa7mBfwfj9c7XMe3',
#  'price': '1.38400000',
#  'origQty': '10.00000000',
#  'executedQty': '10.00000000',
#  'cummulativeQuoteQty': '13.84000000',
#  'status': 'FILLED',
#  'timeInForce': 'GTC',
#  'type': 'LIMIT',
#  'side': 'BUY',
#  'stopPrice': '0.00000000',
#  'icebergQty': '0.00000000',
#  'time': 1695096585437,
#  'updateTime': 1695103581610,
#  'isWorking': True,
#  'workingTime': 1695096585437,
#  'origQuoteOrderQty': '0.00000000',
#  'selfTradePreventionMode': 'NONE'}

# %%
all_orders = client.get_all_orders(symbol='OPUSDT')

# %%
order = client.create_test_order(
    symbol="OPUSDT",
    side=SIDE_SELL,
    type=ORDER_TYPE_TAKE_PROFIT_LIMIT,
    timeInForce=TIME_IN_FORCE_GTC,
    quantity=9,
    stopPrice
    trailingDelta
    price='0.00001')
# Out:
#   Cell In[24], line 7
#     stopPrice
#     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
order = client.create_oco_order(
    symbol='OPUSDT',
    side=SIDE_SELL,
    type=ORDER_TYPE_TAKE_PROFIT_LIMIT,
    stopLimitTimeInForce=TIME_IN_FORCE_GTC,
    quantity=100,
    stopPrice='1.394',
    stopLimitPrice='1.395',
)
# Out:
# 15

# %%
all_orders[-1]
# Out:
# {'symbol': 'OPUSDT',
#  'orderId': 739197567,
#  'orderListId': -1,
#  'clientOrderId': 'dMjyZvwa7mBfwfj9c7XMe3',
#  'price': '1.38400000',
#  'origQty': '10.00000000',
#  'executedQty': '10.00000000',
#  'cummulativeQuoteQty': '13.84000000',
#  'status': 'FILLED',
#  'timeInForce': 'GTC',
#  'type': 'LIMIT',
#  'side': 'BUY',
#  'stopPrice': '0.00000000',
#  'icebergQty': '0.00000000',
#  'time': 1695096585437,
#  'updateTime': 1695103581610,
#  'isWorking': True,
#  'workingTime': 1695096585437,
#  'origQuoteOrderQty': '0.00000000',
#  'selfTradePreventionMode': 'NONE'}

# %%
all_orders[-2]
# Out:
# {'symbol': 'OPUSDT',
#  'orderId': 734710308,
#  'orderListId': -1,
#  'clientOrderId': '1',
#  'price': '1.30000000',
#  'origQty': '5.00000000',
#  'executedQty': '0.00000000',
#  'cummulativeQuoteQty': '0.00000000',
#  'status': 'CANCELED',
#  'timeInForce': 'GTC',
#  'type': 'LIMIT',
#  'side': 'BUY',
#  'stopPrice': '0.00000000',
#  'icebergQty': '0.00000000',
#  'time': 1694679904840,
#  'updateTime': 1694683396364,
#  'isWorking': True,
#  'workingTime': 1694679904840,
#  'origQuoteOrderQty': '0.00000000',
#  'selfTradePreventionMode': 'NONE'}

# %%
info = client.get_account().get('balances')

# %%
info
# Out:
# [{'asset': 'BTC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LTC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ETH', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NEO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BNB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'QTUM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EOS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SNT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BNT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GAS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BCC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'USDT', 'free': '2.02200125', 'locked': '0.00000000'},
#  {'asset': 'HSR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'OAX', 'free': '0.00000000', 'locked': '0.00000000'},
# ...

# %%
{item.get("asset"): item for item in info}
# Out:
# {'BTC': {'asset': 'BTC', 'free': '0.00000000', 'locked': '0.00000000'},
#  'LTC': {'asset': 'LTC', 'free': '0.00000000', 'locked': '0.00000000'},
#  'ETH': {'asset': 'ETH', 'free': '0.00000000', 'locked': '0.00000000'},
#  'NEO': {'asset': 'NEO', 'free': '0.00000000', 'locked': '0.00000000'},
#  'BNB': {'asset': 'BNB', 'free': '0.00000000', 'locked': '0.00000000'},
#  'QTUM': {'asset': 'QTUM', 'free': '0.00000000', 'locked': '0.00000000'},
#  'EOS': {'asset': 'EOS', 'free': '0.00000000', 'locked': '0.00000000'},
#  'SNT': {'asset': 'SNT', 'free': '0.00000000', 'locked': '0.00000000'},
#  'BNT': {'asset': 'BNT', 'free': '0.00000000', 'locked': '0.00000000'},
#  'GAS': {'asset': 'GAS', 'free': '0.00000000', 'locked': '0.00000000'},
#  'BCC': {'asset': 'BCC', 'free': '0.00000000', 'locked': '0.00000000'},
#  'USDT': {'asset': 'USDT', 'free': '15.71200125', 'locked': '0.00000000'},
#  'HSR': {'asset': 'HSR', 'free': '0.00000000', 'locked': '0.00000000'},
# ...
